# %% [markdown]
# # 📋 PHÂN CÔNG NHIỆM VỤ – FINAL PROJECT AI (503043)
# **Môn học:** Introduction to Artificial Intelligence
# **Số thành viên:** 3 người
# **Thời gian:** 6 tuần
# **Tổng điểm:** 10.0 điểm
#
# ---
#
# ## 🗂️ TỔNG QUAN ĐỀ BÀI
#
# | Task | Nội dung | Điểm |
# |------|----------|------|
# | Task 1 | Local Search (Simulated Annealing) | 2.0 |
# | Task 2 | Adversarial Search (Tic-Tac-Toe + Alpha-Beta) | 2.0 |
# | Task 3 | Constraint Satisfaction Problems (CSP + PySAT) | 2.0 |
# | Task 4 | Propositional Logic Inference (Forward/Backward Chaining) | 2.0 |
# | Task 5 | Report (IEEE) + Interview | 2.0 |
# | **Tổng** | | **10.0** |
#
# ---
#
# ## ⚖️ TỔNG KẾT PHÂN CÔNG (CÂN BẰNG NHẤT)
#
# > Task 5 (Báo cáo IEEE): **Cả 3 cùng vào Overleaf tự viết section của mình.** **TV1 chủ trì tạo Template & nộp bài.**
#
# | Thành viên | Tasks code | Điểm code | Báo cáo | Tổng |
# |-----------|------------|-----------|---------|------|
# | **TV1** (Trưởng nhóm) | Task 1 + Task 4 câu 1 (graphviz) | 2.5 đ | lead ~1.0 đ | **~3.50 đ** |
# | **TV2** | Task 2 + Task 4 câu 2 (Forward Chaining) | 2.5 đ | section ~0.67 đ | **~3.17 đ** |
# | **TV3** | Task 3 + Task 4 câu 3 & 4 (BC + Experiment) | 3.0 đ | section ~0.67 đ | **~3.67 đ** |
#
# > 💡 *Phân bổ rất hợp lý: TV3 code nhiều nhất (3.0đ) nên phần báo cáo chỉ cần tự vào Overleaf viết cho Task của mình. TV1 code ít hơn một chút nên sẽ gánh phần chủ trì Overleaf, làm Abstract & nộp bài.*
#
# **Cách chia báo cáo (Task 5):**
# | Thành viên | Tự viết section trên Overleaf | Vai trò thêm (Chủ trì Overleaf) |
# |-----------|------------------------------|--------------------------------|
# | **TV1** | Section Task 1 + Task 4 câu 1| Tạo template, mời m.người vào, viết Abstract + Conclusion, nén nộp bài |
# | **TV2** | Section Task 2 + Task 4 câu 2| Review báo cáo chung |
# | **TV3** | Section Task 3 + Task 4 câu 3&4| Quay video demo (nếu cần) |
#
# ---
#
# ## 👥 PHÂN CÔNG CHI TIẾT
#
# ### 🔵 Thành viên 1 (TV1) — *Trưởng nhóm*
# **Phụ trách:** Task 1 (Local Search) + Task 4 câu 1 + Chủ trì Báo Cáo
#
# | Nhiệm vụ | Mô tả chi tiết | Điểm |
# |----------|---------------|------|
# | **Task 1 – Local Search** | Implement Simulated Annealing Search trong `search.py` | 2.0 |
# | ↳ Hàng xóm (neighbors) | Mỗi state có tối đa 8 neighbor theo 8 hướng {N,E,W,S,NW,SW,NE,SE} | 0.25 |
# | ↳ Schedule function sd1 | Hàm lịch trình: t tăng thì T giảm (cooling schedule) | 0.25 |
# | ↳ Schedule function sd2 | Năng lượng bổ sung tỷ lệ nghịch với độ dốc (slope) bề mặt | 0.25 |
# | ↳ Experiment | So sánh best z-value của sd1 vs sd2 + số bước chạy | 0.25 |
# | ↳ Visualization | 2 hàm: vẽ bề mặt 3D + vẽ đường đi tìm kiếm (dùng `viz3d.py`) | 0.5 |
# | ↳ OOP | Tổ chức code theo mô hình OOP, gọn gàng | 0.5 |
# | **Task 4 – câu 1** | Đọc file clauses, vẽ directed graph minh họa KB bằng `graphviz` | 0.5 |
# | **Task 5 – Báo cáo (Lead)**| Tạo template IEEE, viết Abstract + Conclusion trên Overleaf | ~1.0 |
# | **Phối hợp nhóm** | Thiết lập repo Git, duyệt file, nén thư mục nộp bài cuối cùng | — |
#
# **Tools:** Python, matplotlib, graphviz, Overleaf, VSCode
# **Tổng:** 2.5đ code + lead báo cáo = **~3.50đ**
#
# ---
#
# ### 🟢 Thành viên 2 (TV2)
# **Phụ trách:** Task 2 (Adversarial Search) + Task 4 câu 2
#
# | Nhiệm vụ | Mô tả chi tiết | Điểm |
# |----------|---------------|------|
# | **Task 2 – Adversarial Search** | Tic-Tac-Toe 3x3, người chơi vs máy | 2.0 |
# | ↳ Game UI (PyGame) | Giao diện thân thiện, click chuột, hiển thị bàn cờ 3x3 | 0.5 |
# | ↳ Alpha-Beta Search | Implement thuật toán Alpha-Beta Pruning điều khiển máy | — |
# | &nbsp;&nbsp;&nbsp;↳ Utility values | Đề xuất giá trị utility cho terminal states | 0.5 |
# | &nbsp;&nbsp;&nbsp;↳ Infinite tree handling | Xử lý cây tìm kiếm vô hạn (depth limit/cycle detection) | 0.5 |
# | ↳ OOP | Tổ chức code theo mô hình OOP, gọn gàng | 0.5 |
# | **Task 4 – câu 2** | Implement Forward Chaining, kiểm tra entailment theo pseudocode | 0.5 |
# | **Task 5 – Báo cáo** | Chủ động truy cập Overleaf tự viết phần Task 2 + Task 4 câu 2 | ~0.67 |
#
# **Tools:** Python, PyGame, VSCode, Jupyter Notebook
# **Lưu ý:** Chia sẻ kết quả hàm FC với TV3 để TV3 chạy experiment so sánh!
# **Tổng:** 2.5đ code + viết report = **~3.17đ**
#
# ---
#
# ### 🔴 Thành viên 3 (TV3)
# **Phụ trách:** Task 3 (CSP) + Task 4 câu 3 & 4 (BC + Experiment)
#
# | Nhiệm vụ | Mô tả chi tiết | Điểm |
# |----------|---------------|------|
# | **Task 3 – CSP** | Tô màu ô trong ma trận m×n theo ràng buộc | 2.0 |
# | ↳ Xác định constraints | Liệt kê tất cả ràng buộc có thể, cho ví dụ | 0.5 |
# | ↳ Generate CNF clauses | Sinh mệnh đề CNF cho tất cả ràng buộc | 0.25 |
# | ↳ Tối ưu CNF | Tìm quy tắc sinh CNF không enumerate, không trùng | 0.25 |
# | ↳ PySAT (Glucose3) | Dùng Glucose3 tìm model thỏa mãn tất cả clauses | 0.25 |
# | ↳ Visualization | Hiển thị kết quả tô màu đỏ/xanh lên ma trận | 0.25 |
# | ↳ OOP | Tổ chức code theo mô hình OOP, gọn gàng | 0.5 |
# | **Task 4 – câu 3** | Implement Backward Chaining, kiểm tra entailment theo pseudocode | 0.5 |
# | **Task 4 – câu 4** | Experiment so sánh FC (của TV2) vs BC: đếm số node "inferred" | 0.5 |
# | **Task 5 – Báo cáo** | Chủ động truy cập Overleaf tự viết phần Task 3 + Task 4 câu 3&4 | ~0.67 |
#
# **Tools:** Python, PySAT, Jupyter Notebook, VSCode
# **Lưu ý:** Rất nhiều code, cần lấy hàm FC của TV2 sớm để làm experiment Task 4.
# **Tổng:** 3.0đ code + viết report = **~3.67đ**
#
# ---
#
# ## 📅 TIMELINE – 6 TUẦN
#
# ```
# Tuần 1 (27/04 – 03/05): Khởi động & Nghiên cứu
# ├── [TV1] Đọc viz3d.py, hiểu không gian 3D, nghiên cứu graphviz + Setup Git
# ├── [TV2] Nghiên cứu PyGame, thiết kế UI Tic-Tac-Toe, đọc FC algorithm
# ├── [TV3] Đọc đề Task 3, nghiên cứu PySAT, đọc BC algorithm
# └── [Cả nhóm] Thống nhất interface hàm FC/BC (TV2↔TV3)
#
# Tuần 2 (04/05 – 10/05): Triển khai cốt lõi
# ├── [TV1] Implement SA (schedule sd1) + Task 4 câu 1 (graphviz) + Tạo template Overleaf share nhóm
# ├── [TV2] Code Alpha-Beta Pruning cơ bản + bắt đầu FC (Task 4 câu 2)
# ├── [TV3] Task 3: xác định constraints + generate CNF
# └── [Checkpoint] Review code, commit Git
#
# Tuần 3 (11/05 – 17/05): Hoàn thiện chức năng chính
# ├── [TV1] Implement sd2 + visualization Task 1 → Task 4 câu 1 done
# ├── [TV2] Xử lý infinite tree + hoàn thiện FC (Task 4 câu 2) → share cho TV3
# ├── [TV3] Task 3: PySAT + visualization + bắt đầu BC (Task 4 câu 3)
# └── [Checkpoint] Demo nội bộ, kiểm tra OOP
#
# Tuần 4 (18/05 – 24/05): Experiment & Hoàn thiện
# ├── [TV1] Experiment sd1 vs sd2, hoàn thiện OOP Task 1
# ├── [TV2] Refactor OOP Task 2, hoàn thiện FC
# ├── [TV3] Hoàn thiện Task 3 OOP + Task 4 câu 4 (experiment FC vs BC)
# └── [Checkpoint] Code freeze Task 1, 2, 3, 4
#
# Tuần 5 (25/05 – 31/05): Viết báo cáo & Quay demo
# ├── [TV1] Tự vào Overleaf viết Abstract, Conclusion, section Task 1 + 4 câu 1
# ├── [TV2] Tự vào Overleaf viết section Task 2 + Task 4 câu 2
# ├── [TV3] Tự vào Overleaf viết section Task 3 + Task 4 câu 3&4
# └── [Cả nhóm] Gửi link demo video vào demo.txt, TV1 lấy file report.pdf
#
# Tuần 6 (01/06 – 06/06): Kiểm tra & Nộp bài
# ├── [Cả nhóm] Chạy lại tất cả, kiểm tra output file .ipynb
# ├── [TV1] Tổng hợp folder: final_<GroupID>_<StudentID>, nén zip, báo nhóm
# ├── [Mỗi người] Tự nộp bài cá nhân trước deadline (theo quy định nhà trường)
# └── [Cả nhóm] Ôn tập phỏng vấn — mỗi người PHẢI hiểu rõ phần mình làm!
# ```
#
# ---
#
# ## ⚠️ LƯU Ý QUAN TRỌNG
#
# - 🚫 **AI tools bị cấm tuyệt đối** → phát hiện = Điểm 0 cả task
# - ⏰ **Nộp trễ = 0 điểm** cho tất cả thành viên
# - 🎤 **Interview bắt buộc** → không giải thích được = Điểm 0 task liên quan
# - 🔗 **TV2 & TV3 phải thống nhất interface hàm FC/BC ngay từ Tuần 1**
#
# **Cấu trúc nộp bài:**
# ```
# final_<GroupID>_<StudentID>/
# ├── source/         ← toàn bộ source code
# ├── report.pdf      ← báo cáo IEEE (≤5 trang)
# └── demo.txt        ← URL video demo
# ```
